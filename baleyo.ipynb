# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
response = requests.get("https://baleyo.com/")
soup = bs(response.content,'html.parser')

# %%
body = soup.body

# %%
body
# Out:
# <body class="">
# <div class="homepage" id="wrapwrap">
# <div class="col-12 col-md-auto order-0 order-md-2 tp-account-info-container p-0 dr_not_in_navbar">
# <ul class="list-inline my-3 m-md-0 tp-account-info tp-tablet-hide-bottom-reached">
# <li class="tp-account-info-item">
# <a aria-label="Search" class="tp-search-popover tp-header-navbar-btn" data-placement="bottom" href="#">
# <i class="fa fa-search tp-header-navbar-btn-icon"></i>
# <small class="tp-header-navbar-btn-lable">Search</small>
# </a>
# </li><li class="tp-account-info-item">
# <header>
# <a aria-label="Cart" class="dr_sale_cart_sidebar o_wsale_my_cart tp-header-navbar-btn position-relative" href="/shop/cart">
# <i class="fa fa-shopping-cart tp-header-navbar-btn-icon"></i>
# <small class="tp-header-navbar-btn-lable">My Cart</small>
# <sup class="my_cart_quantity badge badge-primary mb-0 font-weight-bold"></sup>
# </a>
# </header>
# </li><li class="tp-account-info-item">
# <header>
# ...
