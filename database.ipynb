# %%
import sqlite3

conn = sqlite3.connect('okdam.db')

cursor = conn.cursor()

# %%
import csv

# %%
create_table_query = """
    CREATE TABLE m1_data_points(
        category TEXT NOT NULL,
        name TEXT NOT NULL,
        old_price INT,
        new_price INT NOT NULL,
        rating_count,
        src TEXT NOT NULL,
        venders TEXT,
        img_src TEXT)
"""

# %%
file = open('okdam.csv','w')
writer = csv.writer(file)
header = ('catagory','name','actual_price','paying_price','rating','src','vendors','img_src')
writer.writerow(header)
   
for row in cursor.execute("select * from m1_data_points"):
    writer.writerow(row)

# %%
cursor.fetchall()
# Out:
# [('Automobiles',
#   'Suzuki Gixxer 150 Black',
#   None,
#   321900,
#   0,
#   'https://www.okdam.com/category/automobiles',
#   None,
#   None),
#  ('Automobiles',
#   'Suzuki Gixxer 150 Blue',
#   None,
#   321900,
#   0,
#   'https://www.okdam.com/category/automobiles',
#   None,
#   None),
#  ('Automobiles',
#   'Suzuki Gixxer 150 White',
#   None,
#   321900,
#   0,
#   'https://www.okdam.com/category/automobiles',
#   None,
#   None),
#  ('Automobiles',
#   'Suzuki Gixxer SF 150 Black',
#   None,
#   377900,
#   0,
#   'https://www.okdam.com/category/automobiles',
#   None,
#   None),
#  ('Automobiles',
#   'Suzuki Gixxer SF 150 Grey',
#   None,
#   377900,
#   0,
#   'https://www.okdam.com/category/automobiles',
#   None,
#   None),
#  ('Automobiles',
#   'Suzuki Gixxer SF 150 Blue',
#   None,
#   377900,
#   0,
#   'https://www.okdam.com/category/automobiles',
#   None,
#   None),
#  ('Automobiles',
#   'Suzuki Gixxer SF 250 Moto GP',
#   None,
#   499900,
#   0,
# ...

# %%
for row in cur.execute('SELECT * FROM species;'):
    print(row)
